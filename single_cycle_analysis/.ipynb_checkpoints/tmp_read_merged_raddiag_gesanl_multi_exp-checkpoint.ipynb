# %%
# read merged diag files for plotting
# initial built: 2025/02/07

import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy

# %%
exps = ['sc_CTRL', 'sc_amsua_ch1']
instr='amsua'
sat='n15'
time='2022070106'

output_root = '/scratch2/GFDL/gfdlscr/Chih-Chi.Hu/compile_radstats/pkl_files_multi_exp'
output_fn   = f"{instr}_{sat}_gesanl_{time}_{'-'.join(exps)}.pkl"

# Reading a pickle file
df = pd.read_pickle(f"{output_root}/{output_fn}")

# %%
df.keys()
# Out:
# Index(['channel', 'lon', 'lat', 'fwater', 'obs', 'clw_obs', 'qc_sc_CTRL_ges',
#        'omf_sc_CTRL_ges', 'omfnbc_sc_CTRL_ges', 'clw_model_sc_CTRL_ges',
#        'clw_sym_sc_CTRL_ges', 'varbc_idx_sc_CTRL_ges',
#        'inner_pres_sc_CTRL_ges', 'inner_t_sc_CTRL_ges', 'inner_qv_sc_CTRL_ges',
#        'inner_ql_sc_CTRL_ges', 'jac_t_sc_CTRL_ges', 'jac_qv_sc_CTRL_ges',
#        'jac_ql_sc_CTRL_ges', 'qc_sc_CTRL_anl', 'omf_sc_CTRL_anl',
#        'omfnbc_sc_CTRL_anl', 'clw_model_sc_CTRL_anl', 'clw_sym_sc_CTRL_anl',
#        'varbc_idx_sc_CTRL_anl', 'inner_pres_sc_CTRL_anl',
#        'inner_t_sc_CTRL_anl', 'inner_qv_sc_CTRL_anl', 'inner_ql_sc_CTRL_anl',
#        'jac_t_sc_CTRL_anl', 'jac_qv_sc_CTRL_anl', 'jac_ql_sc_CTRL_anl',
#        'qc_sc_amsua_ch1_ges', 'omf_sc_amsua_ch1_ges',
#        'omfnbc_sc_amsua_ch1_ges', 'clw_model_sc_amsua_ch1_ges',
#        'clw_sym_sc_amsua_ch1_ges', 'varbc_idx_sc_amsua_ch1_ges',
#        'inner_pres_sc_amsua_ch1_ges', 'inner_t_sc_amsua_ch1_ges',
#        'inner_qv_sc_amsua_ch1_ges', 'inner_ql_sc_amsua_ch1_ges',
#        'jac_t_sc_amsua_ch1_ges', 'jac_qv_sc_amsua_ch1_ges',
#        'jac_ql_sc_amsua_ch1_ges', 'qc_sc_amsua_ch1_anl',
#        'omf_sc_amsua_ch1_anl', 'omfnbc_sc_amsua_ch1_anl',
#        'clw_model_sc_amsua_ch1_anl', 'clw_sym_sc_amsua_ch1_anl',
#        'varbc_idx_sc_amsua_ch1_anl', 'inner_pres_sc_amsua_ch1_anl',
#        'inner_t_sc_amsua_ch1_anl', 'inner_qv_sc_amsua_ch1_anl',
#        'inner_ql_sc_amsua_ch1_anl', 'jac_t_sc_amsua_ch1_anl',
#        'jac_qv_sc_amsua_ch1_anl', 'jac_ql_sc_amsua_ch1_anl'],
#       dtype='object')

# %%
# several useful tips:

# group the rows into "observation data point"
# each data point = an observation at a certain location:
group_df = df.groupby(['lat', 'lon'])

# to see the # of data point:
ndata = len(list(group_df))
print(f'# of data point = {ndata}')

# to check the data frame of a specific data point:
#data_idx = 0
#list(group_df)[data_idx][1]

# to retrieve the data from group_df:
#for key, group in group_df:
#    print(key)
#    print(type(group))
# Out:
# # of data point = 2981

# %%
# Examples:

# Plot the data point distribution:

# retrieve the data point:
latd = []; lond = []; 

for key, group in group_df:
    latd.append(key[0])
    lond.append(key[1])    

fig = plt.figure(figsize=(14,5))
ax = fig.add_subplot(projection=ccrs.PlateCarree())

ax.coastlines()
scatter1 = ax.scatter(lond, latd, s=5)
#scatter1 = ax.scatter(54.8, -13.6, s=50, color='red')

gl = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False  # Hide labels on the top side
gl.right_labels = False  # Hide labels on the right side
#ax.set_title(f'{exptest} -  {expref}  {instr}-{sat} channel-{chn} {gesanl} {time}')
cbar = fig.colorbar(scatter1,location='right',aspect=40)
#cbar.set_label('dT (K)', fontsize=14)

# %%
# Examples 
# Plot CH1 omf spatial distribution:

tmpdf = df[df['channel'] == 1]
lond = tmpdf['lon']
latd = tmpdf['lat']
omfd = tmpdf['omf_sc_CTRL_ges']

fig = plt.figure(figsize=(14,5))
ax = fig.add_subplot(projection=ccrs.PlateCarree())

ax.coastlines()
scatter1 = ax.scatter(lond, latd, c=omfd, s=5,  vmin=-5, vmax=5, cmap='RdBu_r')
scatter2 = ax.scatter(54.8, -13.6, s=50, edgecolor='red', facecolors='none', linewidth=2)

gl = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False  # Hide labels on the top side
gl.right_labels = False  # Hide labels on the right side
#ax.set_title(f'{exptest} -  {expref}  {instr}-{sat} channel-{chn} {gesanl} {time}')
cbar = fig.colorbar(scatter1,location='right',aspect=40)
#cbar.set_label('dT (K)', fontsize=14)

# %%
# Example:
# Plot the vertical profile of a given observation point:

# filter data criterion (e.g., filter out land):
tmpdf = df[df['fwater']>=0.99]

# group data into observation point:
group_df = tmpdf.groupby(['lat', 'lon'])

# %%
# select observation point:
idx = 1000 # the index for the observation point:
obs_pt_df = list(group_df)[idx][1]

# %%
obs_pt_df.keys()
# Out:
# Index(['channel', 'lon', 'lat', 'fwater', 'obs', 'clw_obs', 'qc_sc_CTRL_ges',
#        'omf_sc_CTRL_ges', 'omfnbc_sc_CTRL_ges', 'clw_model_sc_CTRL_ges',
#        'clw_sym_sc_CTRL_ges', 'varbc_idx_sc_CTRL_ges',
#        'inner_pres_sc_CTRL_ges', 'inner_t_sc_CTRL_ges', 'inner_qv_sc_CTRL_ges',
#        'inner_ql_sc_CTRL_ges', 'jac_t_sc_CTRL_ges', 'jac_qv_sc_CTRL_ges',
#        'jac_ql_sc_CTRL_ges', 'qc_sc_CTRL_anl', 'omf_sc_CTRL_anl',
#        'omfnbc_sc_CTRL_anl', 'clw_model_sc_CTRL_anl', 'clw_sym_sc_CTRL_anl',
#        'varbc_idx_sc_CTRL_anl', 'inner_pres_sc_CTRL_anl',
#        'inner_t_sc_CTRL_anl', 'inner_qv_sc_CTRL_anl', 'inner_ql_sc_CTRL_anl',
#        'jac_t_sc_CTRL_anl', 'jac_qv_sc_CTRL_anl', 'jac_ql_sc_CTRL_anl',
#        'qc_sc_amsua_ch1_ges', 'omf_sc_amsua_ch1_ges',
#        'omfnbc_sc_amsua_ch1_ges', 'clw_model_sc_amsua_ch1_ges',
#        'clw_sym_sc_amsua_ch1_ges', 'varbc_idx_sc_amsua_ch1_ges',
#        'inner_pres_sc_amsua_ch1_ges', 'inner_t_sc_amsua_ch1_ges',
#        'inner_qv_sc_amsua_ch1_ges', 'inner_ql_sc_amsua_ch1_ges',
#        'jac_t_sc_amsua_ch1_ges', 'jac_qv_sc_amsua_ch1_ges',
#        'jac_ql_sc_amsua_ch1_ges', 'qc_sc_amsua_ch1_anl',
#        'omf_sc_amsua_ch1_anl', 'omfnbc_sc_amsua_ch1_anl',
#        'clw_model_sc_amsua_ch1_anl', 'clw_sym_sc_amsua_ch1_anl',
#        'varbc_idx_sc_amsua_ch1_anl', 'inner_pres_sc_amsua_ch1_anl',
#        'inner_t_sc_amsua_ch1_anl', 'inner_qv_sc_amsua_ch1_anl',
#        'inner_ql_sc_amsua_ch1_anl', 'jac_t_sc_amsua_ch1_anl',
#        'jac_qv_sc_amsua_ch1_anl', 'jac_ql_sc_amsua_ch1_anl'],
#       dtype='object')

# %%
obs_pt_df[['omf_sc_CTRL_ges','omf_sc_CTRL_anl','omf_sc_amsua_ch1_ges','omf_sc_amsua_ch1_anl']]
# Out:
#       omf_sc_CTRL_ges  omf_sc_CTRL_anl  omf_sc_amsua_ch1_ges  \
# 2372        -3.166652         1.291538             -2.691835
# 2373        -1.994127         0.340391             -1.994127
# 2374        -2.515470        -1.148142             -2.515470
# 2375        -0.404872        -0.320204             -0.404872
# 2376        -0.202444        -0.279398             -0.202444
# 2377        -6.304331        -2.408944             -6.304331
#
#       omf_sc_amsua_ch1_anl
# 2372              1.587000
# 2373              0.294437
# 2374             -1.173458
# 2375             -0.324823
# 2376             -0.280155
# 2377             -2.479323

# %%
# select which channel to plot
test_ch = 1
obs_pt_ch_df = obs_pt_df[obs_pt_df['channel'] == test_ch]

lat = obs_pt_ch_df['lat'].values[0]
lon = obs_pt_ch_df['lon'].values[0]
fwater = obs_pt_ch_df['fwater'].values[0]

qv_ges = {};
qv_anl = {};

for exp in exps:
    pres = np.array(obs_pt_ch_df[f"inner_pres_{exp}_ges"].values[0]) # should be the same across all experiments
    qv_ges[exp] = np.array(obs_pt_ch_df[f'inner_qv_{exp}_ges'].values[0])
    qv_anl[exp] = np.array(obs_pt_ch_df[f'inner_qv_{exp}_anl'].values[0])

# %%
expref  = exps[0]
exptest = exps[1]

fig, ax = plt.subplots(figsize=(6,5))
ax.plot(qv_ges[expref], pres, label=f'qv ges ({expref})', color='blue', linestyle='-')
ax.plot(qv_anl[expref], pres, label=f'qv anl ({expref})', color='blue', linestyle='--')

ax.axvline(x=0, color='black', linestyle=':', linewidth=2)
ax.set_ylim(1000,0)
#ax.set_xlabel(r'$ \partial T_B / \partial T$  [K/K]', fontsize=14)
ax.set_ylabel('pressure  [hPa]', fontsize=14)
ax.grid(True)
ax.legend()
ax.set_title(f'lat = {lat:.1f}, lon = {lon:.1f}, fwater = {fwater:.2f}')
# Out:
# Text(0.5, 1.0, 'lat = -13.6, lon = 54.8, fwater = 1.00')

# %%
fig, ax = plt.subplots(figsize=(6,5))
ax.plot(qv_anl[exptest] - qv_anl[expref], pres, color='blue', label=rf'$\Delta q_v$')
ax.axvline(x=0, color='black', linestyle=':', linewidth=2)
ax.set_ylim(1000,0)
#ax.set_xlabel(r'$ \partial T_B / \partial T$  [K/K]', fontsize=14)
ax.set_ylabel('pressure  [hPa]', fontsize=14)
ax.grid(True)
ax.legend()
ax.set_title(f'lat = {lat:.1f}, lon = {lon:.1f}, fwater = {fwater:.2f}')
# Out:
# Text(0.5, 1.0, 'lat = -13.6, lon = 54.8, fwater = 1.00')
