# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt

# %%
rr = nc.Dataset("/scratch2/GFDL/gfdlscr/Chih-Chi.Hu/OMF_analysis/amsua_data/diag_amsua_n18_ges.2022061500.nc4")
#rr = nc.Dataset("/scratch2/GFDL/gfdlscr/Mingjing.Tong/scrub/radstats/cris/s2022_C192_v2p5_edmf1ens0/diag_cris-fsr_npp_ges.2022070806.nc4")
#print(rr)                  # get all info
#print(rr.variables.keys())   # get all variables names
#tt = rr.variables['Obs_Time'][:] ???

# %%
use_flag = rr.variables['use_flag'][:]
chidx    = rr.variables['Channel_Index'][:]
chinfoidx= rr.variables['chaninfoidx'][:]
#print(use_flag)
#print(len(use_flag))
#print(chidx)
#print(len(chidx))
#print(chinfoidx)
#print(chidx==chinfoidx)

# %%
inv_obserr = rr.variables['Inverse_Observation_Error'][:]
obserr     = rr.variables['Sym_Observation_Error'][:]
clw_obs    = rr.variables['clw_obs'][:]
clw_model  = rr.variables['clw_guess_retrieval'][:]
ch         = rr.variables['Channel_Index'][:]
qc         = rr.variables['QC_Flag'][:]
omf        = rr.variables['Obs_Minus_Forecast_adjusted'][:]
symcloud   = 0.5*(clw_obs + clw_model)
#omf = rr.variables['Obs_Minus_Forecast_adjusted'][:]
#omf = rr.variables['Obs_Minus_Forecast_adjusted']
#print(omf)       # print var info
#omf.dimensions   # check var dimensions
#omf.shape        # check var dimensions (in number)
#omf_array = omf[:] # translate to numpy array
#omf_array.shape

# %%
plt.scatter(symcloud[np.where(ch==1)], obserr[np.where(ch==1)],s=5)
plt.xlim([0,1])
# Out:
# (0.0, 1.0)

# %%
#print(np.where(qc==3))
#plt.plot(omf[np.where(qc==53)])
print(max(inv_obserr[np.where(qc==53)]))
# Out:
# 0.0

# %%
use = np.where((qc == 3)&(ch==15))
#print(use[0].shape)
obserr_use     = obserr[use]
inv_obserr_use = inv_obserr[use]
cloud_use      = symcloud[use]

# %%
plt.scatter(cloud_use, obserr_use)
plt.xlim([0,1])
plt.show()

# %%
plt.plot(obserr_use)
plt.plot(1/inv_obserr_use)
plt.show()

# %%
plt.hist(1/inv_obserr_use - obserr_use)
# Out:
# (array([5.131e+03, 4.420e+02, 1.380e+02, 7.800e+01, 6.400e+01, 3.300e+01,
#         1.100e+01, 5.000e+00, 1.000e+00, 1.000e+00]),
#  array([2.6209831e-02, 9.4315453e+00, 1.8836880e+01, 2.8242214e+01,
#         3.7647549e+01, 4.7052883e+01, 5.6458221e+01, 6.5863556e+01,
#         7.5268890e+01, 8.4674225e+01, 9.4079559e+01], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
clw_obs = rr.variables['clw_obs'][:]
plt.hist(omf[np.where((clw_obs>0.7)&(clw_obs<1))],bins=np.arange(-15,15,1))
plt.show()
